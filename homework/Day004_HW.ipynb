# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"12486620016","type":"PushEvent","actor":{"id":29052595,"login":"avijitliberty","display_login":"avijitliberty","gravatar_id":"","url":"https://api.github.com/users/avijitliberty","avatar_url":"https://avatars.githubusercontent.com/u/29052595?"},"repo":{"id":266886028,"name":"avijitliberty/honeycomb","url":"https://api.github.com/repos/avijitliberty/honeycomb"},"payload":{"push_id":5153505791,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"baff1230a7b84e08c5a960957d22504ef648daf0","before":"deb6dcda151f980e983bbf6b1af6a38f5b9924ce","commits":[{"sha":"baff1230a7b84e08c5a960957d22504ef648daf0","author":{"email":"avijit.liberty@gmail.com","name":"Avijit Chatterjee"},"message":"Update from Forestry.io\\nAvijit Chatterjee created static/uploads/s3-storage-tiers-1.png","distinct":true,"url":"https://api.github.com/repos/avijitliberty/honeycomb/commits/baff1230a7b84e08c5a960957d22504ef648daf0"}]},"public":true,"created_at":"2020-05-31T03:30:29Z"},{"id":"12486620014","type":"PushEvent","actor":{"id":1939514,"login":"jlippold","display_login":"jlippold","gravatar_id":"","url":"https://api.github.com/users/jlippold","avatar_url":"https://avatars.githubusercontent.com/u/1939514?"},"repo":{"id":114825753,"name":"jlippold/tweakCompatible","url":"https://api.github.com/repos/jlippold/tweakCompatible"},"payload":{"push_id":5153505790,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"841ba4435a191c7a8c10b70b012c12e0b7b93d7f","before":"a4268bb94d37f1438d9b7138fd16638da90cde64","commits":[{"sha":"841ba4435a191c7a8c10b70b012c12e0b7b93d7f","author":{"email":"jlippold@datacation.com","name":"jlippold"},"message":"fixes #126013","distinct":true,"url":"https://api.github.com/repos/jlippold/tweakCompatible/commits/841ba4435a191c7a8c10b70b012c12e0b7b93d7f"}]},"public":true,"created_at":"2020-05-31T03:30:29Z"},{"id":"12486620017","type":"CreateEvent","actor":{"id":59357719,"login":"aagezai","display_login":"aagezai","gravatar_id":"","url":"https://api.github.com/users/aagezai","avatar_url":"https://avatars.githubusercontent.com/u/59357719?"},"repo":{"id":268167565,"name":"The-RedSeaCamels-WAA-Project/RedSeaCamels-OnlineShopping","url":"https://api.github.com/repos/The-RedSeaCamels-WAA-Project/RedSeaCamels-OnlineShopping"},"payload":{"ref":"aaronbranch","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-05-31T03:30:29Z","org":{"id":66185579,"login":"The-RedSeaCamels-WAA-Project","gravatar_id":"","url":"https://api.github.com/orgs/The-RedSeaCamels-WAA-Project","avatar_url":"https://avatars.githubusercontent.com/u/66185579?"}},{"id":"12486620010","type":"CreateEvent","actor":{"id":1497132,"login":"colistro123","display_login":"colistro123","gravatar_id":"","url":"https://api.github.com/users/colistro123","avatar_url":"https://avatars.githubusercontent.com/u/1497132?"},"repo":{"id":268202024,"name":"colistro123/mta-amx-module","url":"https://api.github.com/repos/colistro123/mta-amx-module"},"payload":{"ref":"master","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-05-31T03:30:29Z"},{"id":"12486620005","type":"PushEvent","actor":{"id":2951285,"login":"samber","display_login":"samber","gravatar_id":"","url":"https://api.github.com/users/samber","avatar_url":"https://avatars.githubusercontent.com/u/2951285?"},"repo":{"id":166562589,"name":"samber/powEUr","url":"https://api.github.com/repos/samber/powEUr"},"payload":{"push_id":5153505781,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"7d9b96179ec524cec4c4f48e7fe03bbc2993d049","before":"17a9f92ec00d2741905266dcf2bb02abb8a751f7","commits":[{"sha":"7d9b96179ec524cec4c4f48e7fe03bbc2993d049","author":{"email":"dev@samuel-berthe.fr","name":"Samuel Berthe"},"message":"Adding 2020-05-31 data","distinct":true,"url":"https://api.github.com/repos/samber/powEUr/commits/7d9b96179ec524cec4c4f48e7fe03bbc2993d049"}]},"public":true,"created_at":"2 ...

# %%
import requests
import json

j = requests.get('https://api.github.com/events')
json.loads(j.text)
# Out:
# [{'id': '12486622452',
#   'type': 'PushEvent',
#   'actor': {'id': 62271262,
#    'login': 'CharlotteWoltanski',
#    'display_login': 'CharlotteWoltanski',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CharlotteWoltanski',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/62271262?'},
#   'repo': {'id': 257466823,
#    'name': 'CharlotteWoltanski/The_IT_World',
#    'url': 'https://api.github.com/repos/CharlotteWoltanski/The_IT_World'},
#   'payload': {'push_id': 5153507369,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2b6894b4b91154a62fbc22a369350a4136540168',
#    'before': 'b570edfee4c5f1aeed7d0df3534a5eaa8e8f5d9c',
#    'commits': [{'sha': '2b6894b4b91154a62fbc22a369350a4136540168',
#      'author': {'email': '62271262+CharlotteWoltanski@users.noreply.github.com',
#       'name': 'Charlotte'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/CharlotteWoltanski/The_IT_World/commits/2b6894b4b91154a62fbc22a369350a4136540168'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:31:38Z'},
#  {'id': '12486622451',
#   'type': 'CreateEvent',
#   'actor': {'id': 47148648,
#    'login': 'svc-software-factory',
#    'display_login': 'svc-software-factory',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/svc-software-factory',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47148648?'},
#   'repo': {'id': 197735801,
#    'name': 'adeo-gitlab/sync-github-gitlab-31',
#    'url': 'https://api.github.com/repos/adeo-gitlab/sync-github-gitlab-31'},
#   'payload': {'ref': '2020-05-31_03-31-26_493_scenario1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-31T03:31:38Z',
#   'org': {'id': 52697831,
#    'login': 'adeo-gitlab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/adeo-gitlab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52697831?'}},
#  {'id': '12486622450',
#   'type': 'CreateEvent',
#   'actor': {'id': 44822033,
#    'login': 'carlos18mz',
#    'display_login': 'carlos18mz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/carlos18mz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44822033?'},
#   'repo': {'id': 268200029,
#    'name': 'carlos18mz/TS_Appweb_BE',
#    'url': 'https://api.github.com/repos/carlos18mz/TS_Appweb_BE'},
#   'payload': {'ref': 'feature-us01',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-31T03:31:38Z'},
#  {'id': '12486622449',
#   'type': 'CreateEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 169821563,
#    'name': 'ajtorres9/andrewjtorr.es',
#    'url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/testing-library/dom-7.7.1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Personal website of Andrew Torres',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-31T03:31:38Z'},
#  {'id': '12486622445',
#   'type': 'WatchEvent',
#   'actor': {'id': 47312692,
#    'login': 'fuchangmeng',
#    'display_login': 'fuchangmeng',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fuchangmeng',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47312692?'},
#   'repo': {'id': 109048947,
#    'name': 'mnielsen/magic_paper',
#    'url': 'https://api.github.com/repos/mnielsen/magic_paper'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-05-31T03:31:38Z'},
#  {'id': '12486622444',
#   'type': 'WatchEvent',
#   'actor': {'id': 20961136,
#    'login': 'yqstar',
#    'display_login': 'yqstar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yqstar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20961136?'},
#   'repo': {'id': 264675954,
#    'name': 'dair-ai/ml-visuals',
#    'url': 'https://api.github.com/repos/dair-ai/ml-visuals'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-05-31T03:31:38Z',
#   'org': {'id': 30384625,
#    'login': 'dair-ai',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/dair-ai',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30384625?'}},
#  {'id': '12486622439',
#   'type': 'PushEvent',
#   'actor': {'id': 44182109,
#    'login': 'hexatedjuice',
#    'display_login': 'hexatedjuice',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hexatedjuice',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44182109?'},
#   'repo': {'id': 267979849,
#    'name': 'hexatedjuice/seersProject',
#    'url': 'https://api.github.com/repos/hexatedjuice/seersProject'},
#   'payload': {'push_id': 5153507363,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/Development',
#    'head': '62428b9ecc1ee5b0a1a1ec0a88aa33387391e268',
#    'before': '57ac07f4c8d010e0ac1b54d266002a50f4bff902',
#    'commits': [{'sha': '62428b9ecc1ee5b0a1a1ec0a88aa33387391e268',
#      'author': {'email': '44182109+hexatedjuice@users.noreply.github.com',
#       'name': 'hexatedjuice'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hexatedjuice/seersProject/commits/62428b9ecc1ee5b0a1a1ec0a88aa33387391e268'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:31:38Z'},
#  {'id': '12486622435',
#   'type': 'PushEvent',
#   'actor': {'id': 47166987,
#    'login': 'pusanmodoki',
#    'display_login': 'pusanmodoki',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pusanmodoki',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47166987?'},
#   'repo': {'id': 244358063,
#    'name': 'pusanmodoki/NORA-INU',
#    'url': 'https://api.github.com/repos/pusanmodoki/NORA-INU'},
#   'payload': {'push_id': 5153507360,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/develop',
#    'head': '592f280b858d0c498153e1769844ff0b551cb589',
#    'before': 'e40aa517ffa99d448922134aa8816855598cce84',
#    'commits': [{'sha': '592f280b858d0c498153e1769844ff0b551cb589',
#      'author': {'email': 'blackdragon.chanp@gmail.com', 'name': 'pusanmodoki'},
#      'message': '動くポイント完成',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pusanmodoki/NORA-INU/commits/592f280b858d0c498153e1769844ff0b551cb589'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:31:38Z'},
#  {'id': '12486622442',
#   'type': 'CreateEvent',
#   'actor': {'id': 365971,
#    'login': 'flavioricardo',
#    'display_login': 'flavioricardo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/flavioricardo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/365971?'},
#   'repo': {'id': 268202486,
#    'name': 'flavioricardo/agendaesports',
#    'url': 'https://api.github.com/repos/flavioricardo/agendaesports'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-31T03:31:38Z'},
#  {'id': '12486622441',
#   'type': 'CreateEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 52560024,
#    'name': 'goblindegook/littlefoot',
#    'url': 'https://api.github.com/repos/goblindegook/littlefoot'},
#   'payload': {'ref': 'renovate/testing-library-dom-7.x',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Footnotes without the footprint.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-31T03:31:38Z'},
#  {'id': '12486622437',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 169821563,
#    'name': 'ajtorres9/andrewjtorr.es',
#    'url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es'},
#   'payload': {'action': 'opened',
#    'number': 1726,
#    'pull_request': {'url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/pulls/1726',
#     'id': 425554948,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDI1NTU0OTQ4',
#     'html_url': 'https://github.com/ajtorres9/andrewjtorr.es/pull/1726',
#     'diff_url': 'https://github.com/ajtorres9/andrewjtorr.es/pull/1726.diff',
#     'patch_url': 'https://github.com/ajtorres9/andrewjtorr.es/pull/1726.patch',
#     'issue_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/issues/1726',
#     'number': 1726,
#     'state': 'open',
#     'locked': False,
#     'title': 'chore(deps-dev): bump @testing-library/dom from 7.7.0 to 7.7.1',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [@testing-library/dom](https://github.com/testing-library/dom-testing-library) from 7.7.0 to 7.7.1.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/testing-library/dom-testing-library/releases">@testing-library/dom\'s releases</a>.</em></p>\n<blockquote>\n<h2>v7.7.1</h2>\n<h2><a href="https://github.com/testing-library/dom-testing-library/compare/v7.7.0...v7.7.1">7.7.1</a> (2020-05-31)</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li>handle ignores for ByText in suggestions (<a href="https://github-redirect.dependabot.com/testing-library/dom-testing-library/issues/597">#597</a>) (<a href="https://github.com/testing-library/dom-testing-library/commit/bec190b8ba0b59a70da7a7814e45cfa53fc54b7c">bec190b</a>)</li>\n</ul>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/testing-library/dom-testing-library/commit/bec190b8ba0b59a70da7a7814e45cfa53fc54b7c"><code>bec190b</code></a> fix: handle ignores for ByText in suggestions (<a href="https://github-redirect.dependabot.com/testing-library/dom-testing-library/issues/597">#597</a>)</li>\n<li><a href="https://github.com/testing-library/dom-testing-library/commit/95bb7f2ed929fed7484dd6f320b5dc80e8f962b0"><code>95bb7f2</code></a> Merge pull request <a href="https://github-redirect.dependabot.com/testing-library/dom-testing-library/issues/596">#596</a> from testing-library/all-contributors/add-smeijer</li>\n<li><a href="https://github.com/testing-library/dom-testing-library/commit/8790b1e4fd00b155fc264d6ab99639131d9a7f50"><code>8790b1e</code></a> docs: update .all-contributorsrc</li>\n<li><a href="https://github.com/testing-library/dom-testing-library/commit/4c1e7041e5d1beb3fd00d9c1300bc05689e1558f"><code>4c1e704</code></a> docs: update README.md</li>\n<li><a href="https://github.com/testing-library/dom-testing-library/commit/56aa6d00580432914d4535aa5280b9112d4c4d71"><code>56aa6d0</code></a> Merge pull request <a href="https://github-redirect.dependabot.com/testing-library/dom-testing-library/issues/595">#595</a> from testing-library/all-contributors/add-benmonro</li>\n<li><a href="https://github.com/testing-library/dom-testing-library/commit/9540572e6cf3b1c00c9a330ec5c722a05a9d636e"><code>9540572</code></a> docs: update .all-contributorsrc</li>\n<li><a href="https://github.com/testing-library/dom-testing-library/commit/edb71f3771b93b0ca3fff66410f78fab6788373a"><code>edb71f3</code></a> docs: update README.md</li>\n<li><a href="https://github.com/testing-library/dom-testing-library/commit/feac795f855f7cdd17fa900f58b5b29a7fc24c40"><code>feac795</code></a> Merge pull request <a href="https://github-redirect.dependabot.com/testing-library/dom-testing-library/issues/594">#594</a> from testing-library/all-contributors/add-appleJax</li>\n<li><a href="https://github.com/testing-library/dom-testing-library/commit/3f8d4bea4747589a563f911544c98270fdc00936"><code>3f8d4be</code></a> docs: update .all-contributorsrc</li>\n<li><a href="https://github.com/testing-library/dom-testing-library/commit/75981fe0ddc1264b28fb5ddb3eb4d00a59fe25b7"><code>75981fe</code></a> docs: update README.md</li>\n<li>See full diff in <a href="https://github.com/testing-library/dom-testing-library/compare/v7.7.0...v7.7.1">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://api.dependabot.com/badges/compatibility_score?dependency-name=@testing-library/dom&package-manager=npm_and_yarn&previous-version=7.7.0&new-version=7.7.1)](https://dependabot.com/compatibility-score/?dependency-name=@testing-library/dom&package-manager=npm_and_yarn&previous-version=7.7.0&new-version=7.7.1)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</su ...
#     'created_at': '2020-05-31T03:31:37Z',
#     'updated_at': '2020-05-31T03:31:37Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/pulls/1726/commits',
#     'review_comments_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/pulls/1726/comments',
#     'review_comment_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/issues/1726/comments',
#     'statuses_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/statuses/79a69ca5cc4e7ecaeb03c032750bf32c56822f04',
#     'head': {'label': 'ajtorres9:dependabot/npm_and_yarn/testing-library/dom-7.7.1',
#      'ref': 'dependabot/npm_and_yarn/testing-library/dom-7.7.1',
#      'sha': '79a69ca5cc4e7ecaeb03c032750bf32c56822f04',
#      'user': {'login': 'ajtorres9',
#       'id': 450495,
#       'node_id': 'MDQ6VXNlcjQ1MDQ5NQ==',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/450495?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ajtorres9',
#       'html_url': 'https://github.com/ajtorres9',
#       'followers_url': 'https://api.github.com/users/ajtorres9/followers',
#       'following_url': 'https://api.github.com/users/ajtorres9/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ajtorres9/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ajtorres9/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ajtorres9/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ajtorres9/orgs',
#       'repos_url': 'https://api.github.com/users/ajtorres9/repos',
#       'events_url': 'https://api.github.com/users/ajtorres9/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ajtorres9/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 169821563,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNjk4MjE1NjM=',
#       'name': 'andrewjtorr.es',
#       'full_name': 'ajtorres9/andrewjtorr.es',
#       'private': False,
#       'owner': {'login': 'ajtorres9',
#        'id': 450495,
#        'node_id': 'MDQ6VXNlcjQ1MDQ5NQ==',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/450495?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ajtorres9',
#        'html_url': 'https://github.com/ajtorres9',
#        'followers_url': 'https://api.github.com/users/ajtorres9/followers',
#        'following_url': 'https://api.github.com/users/ajtorres9/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ajtorres9/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ajtorres9/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ajtorres9/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ajtorres9/orgs',
#        'repos_url': 'https://api.github.com/users/ajtorres9/repos',
#        'events_url': 'https://api.github.com/users/ajtorres9/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ajtorres9/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/ajtorres9/andrewjtorr.es',
#       'description': 'Personal website of Andrew Torres',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es',
#       'forks_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/forks',
#       'keys_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/teams',
#       'hooks_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/events',
#       'assignees_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/tags',
#       'blobs_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/languages',
#       'stargazers_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/subscription',
#       'commits_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/merges',
#       'archive_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/downloads',
#       'issues_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/deployments',
#       'created_at': '2019-02-09T01:43:37Z',
#       'updated_at': '2020-05-30T23:03:39Z',
#       'pushed_at': '2020-05-31T03:31:37Z',
#       'git_url': 'git://github.com/ajtorres9/andrewjtorr.es.git',
#       'ssh_url': 'git@github.com:ajtorres9/andrewjtorr.es.git',
#       'clone_url': 'https://github.com/ajtorres9/andrewjtorr.es.git',
#       'svn_url': 'https://github.com/ajtorres9/andrewjtorr.es',
#       'homepage': 'https://andrewjtorr.es',
#       'size': 5831,
#       'stargazers_count': 2,
#       'watchers_count': 2,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 2,
#       'default_branch': 'master'}},
#     'base': {'label': 'ajtorres9:master',
#      'ref': 'master',
#      'sha': '8c0af01e256ecdde626c29b4104c9f6913ff0fda',
#      'user': {'login': 'ajtorres9',
#       'id': 450495,
#       'node_id': 'MDQ6VXNlcjQ1MDQ5NQ==',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/450495?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ajtorres9',
#       'html_url': 'https://github.com/ajtorres9',
#       'followers_url': 'https://api.github.com/users/ajtorres9/followers',
#       'following_url': 'https://api.github.com/users/ajtorres9/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ajtorres9/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ajtorres9/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ajtorres9/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ajtorres9/orgs',
#       'repos_url': 'https://api.github.com/users/ajtorres9/repos',
#       'events_url': 'https://api.github.com/users/ajtorres9/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ajtorres9/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 169821563,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNjk4MjE1NjM=',
#       'name': 'andrewjtorr.es',
#       'full_name': 'ajtorres9/andrewjtorr.es',
#       'private': False,
#       'owner': {'login': 'ajtorres9',
#        'id': 450495,
#        'node_id': 'MDQ6VXNlcjQ1MDQ5NQ==',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/450495?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ajtorres9',
#        'html_url': 'https://github.com/ajtorres9',
#        'followers_url': 'https://api.github.com/users/ajtorres9/followers',
#        'following_url': 'https://api.github.com/users/ajtorres9/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ajtorres9/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ajtorres9/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ajtorres9/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ajtorres9/orgs',
#        'repos_url': 'https://api.github.com/users/ajtorres9/repos',
#        'events_url': 'https://api.github.com/users/ajtorres9/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ajtorres9/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/ajtorres9/andrewjtorr.es',
#       'description': 'Personal website of Andrew Torres',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es',
#       'forks_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/forks',
#       'keys_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/teams',
#       'hooks_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/events',
#       'assignees_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/tags',
#       'blobs_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/languages',
#       'stargazers_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/subscription',
#       'commits_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/merges',
#       'archive_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/downloads',
#       'issues_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/deployments',
#       'created_at': '2019-02-09T01:43:37Z',
#       'updated_at': '2020-05-30T23:03:39Z',
#       'pushed_at': '2020-05-31T03:31:37Z',
#       'git_url': 'git://github.com/ajtorres9/andrewjtorr.es.git',
#       'ssh_url': 'git@github.com:ajtorres9/andrewjtorr.es.git',
#       'clone_url': 'https://github.com/ajtorres9/andrewjtorr.es.git',
#       'svn_url': 'https://github.com/ajtorres9/andrewjtorr.es',
#       'homepage': 'https://andrewjtorr.es',
#       'size': 5831,
#       'stargazers_count': 2,
#       'watchers_count': 2,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 2,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/pulls/1726'},
#      'html': {'href': 'https://github.com/ajtorres9/andrewjtorr.es/pull/1726'},
#      'issue': {'href': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/issues/1726'},
#      'comments': {'href': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/issues/1726/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/pulls/1726/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/pulls/1726/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/ajtorres9/andrewjtorr.es/statuses/79a69ca5cc4e7ecaeb03c032750bf32c56822f04'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 5,
#     'deletions': 5,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2020-05-31T03:31:38Z'},
#  {'id': '12486622433',
#   'type': 'PushEvent',
#   'actor': {'id': 36196578,
#    'login': 'xnuxer17',
#    'display_login': 'xnuxer17',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xnuxer17',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36196578?'},
#   'repo': {'id': 253631758,
#    'name': 'ENJE-DEV/BIMBLE-UNUJA',
#    'url': 'https://api.github.com/repos/ENJE-DEV/BIMBLE-UNUJA'},
#   'payload': {'push_id': 5153507365,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '89c9f7637c4ae0551724724b5a1feaa177e9a4fa',
#    'before': '7860ef81171ba97b4ec9f1a756fcb2ee8fb822a5',
#    'commits': [{'sha': '89c9f7637c4ae0551724724b5a1feaa177e9a4fa',
#      'author': {'email': 'do.crazy192@gmail.com', 'name': 'mhafet17'},
#      'message': 'memperbaiki data order',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ENJE-DEV/BIMBLE-UNUJA/commits/89c9f7637c4ae0551724724b5a1feaa177e9a4fa'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:31:38Z',
#   'org': {'id': 62368723,
#    'login': 'ENJE-DEV',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ENJE-DEV',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/62368723?'}},
#  {'id': '12486622423',
#   'type': 'PushEvent',
#   'actor': {'id': 59677854,
#    'login': 'RHYDYO',
#    'display_login': 'RHYDYO',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RHYDYO',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59677854?'},
#   'repo': {'id': 232721657,
#    'name': 'RHYDYO/repository2',
#    'url': 'https://api.github.com/repos/RHYDYO/repository2'},
#   'payload': {'push_id': 5153507348,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6492dbdeeb76a91cc705953ff506af8accea5af9',
#    'before': '3d242802cb6540fdfef631272c816b29bc25eee1',
#    'commits': [{'sha': '6492dbdeeb76a91cc705953ff506af8accea5af9',
#      'author': {'email': '59677854+RHYDYO@users.noreply.github.com',
#       'name': 'RHYDYO'},
#      'message': 'kill list',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/RHYDYO/repository2/commits/6492dbdeeb76a91cc705953ff506af8accea5af9'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:31:38Z'},
#  {'id': '12486622428',
#   'type': 'PushEvent',
#   'actor': {'id': 66191699,
#    'login': 'VisualBuddhist',
#    'display_login': 'VisualBuddhist',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/VisualBuddhist',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66191699?'},
#   'repo': {'id': 268199747,
#    'name': 'VisualBuddhist/quipside',
#    'url': 'https://api.github.com/repos/VisualBuddhist/quipside'},
#   'payload': {'push_id': 5153507352,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1dabc74ce03f64bf606b820337a3de9827d2d771',
#    'before': '0202015c756ea80693e3a940f824ef9d99ac4ba7',
#    'commits': [{'sha': '1dabc74ce03f64bf606b820337a3de9827d2d771',
#      'author': {'email': '66191699+VisualBuddhist@users.noreply.github.com',
#       'name': 'VisualBuddhist'},
#      'message': 'Updated README\n\ngod fuck so much fine detailing\r\njk I added spaces',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/VisualBuddhist/quipside/commits/1dabc74ce03f64bf606b820337a3de9827d2d771'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:31:38Z'},
#  {'id': '12486622429',
#   'type': 'PushEvent',
#   'actor': {'id': 38567338,
#    'login': 'dzungpng',
#    'display_login': 'dzungpng',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dzungpng',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38567338?'},
#   'repo': {'id': 248070914,
#    'name': 'dzungpng/here-to-serve',
#    'url': 'https://api.github.com/repos/dzungpng/here-to-serve'},
#   'payload': {'push_id': 5153507356,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '61ef83172df3f245b6cd6afefc3c739786ed4c4e',
#    'before': '469fa545a258606090ff0fb5e5333eca2cc15e7a',
#    'commits': [{'sha': '4a1a7cfb2d49d29cc94cd04ea5caf7b36b78cbe5',
#      'author': {'email': 'dzungng@seas.upenn.edu', 'name': 'Dzung Nguyen'},
#      'message': 'Color-coded the events',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/dzungpng/here-to-serve/commits/4a1a7cfb2d49d29cc94cd04ea5caf7b36b78cbe5'},
#     {'sha': '61ef83172df3f245b6cd6afefc3c739786ed4c4e',
#      'author': {'email': '38567338+dzungpng@users.noreply.github.com',
#       'name': 'Dzung Nguyen'},
#      'message': 'Merge pull request #64 from dzungpng/calendar-event-color\n\nColor-coded the events',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dzungpng/here-to-serve/commits/61ef83172df3f245b6cd6afefc3c739786ed4c4e'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:31:38Z'},
#  {'id': '12486622427',
#   'type': 'PushEvent',
#   'actor': {'id': 58341448,
#    'login': 'kam1n0',
#    'display_login': 'kam1n0',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kam1n0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58341448?'},
#   'repo': {'id': 268196490,
#    'name': 'kam1n0/suid-abuse-bash-debug',
#    'url': 'https://api.github.com/repos/kam1n0/suid-abuse-bash-debug'},
#   'payload': {'push_id': 5153507347,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6f246d39f864904134b39abf8d813e9aa7ea27e3',
#    'before': '9a5168b73208175deeb754cc18ee5585e9019086',
#    'commits': [{'sha': '6f246d39f864904134b39abf8d813e9aa7ea27e3',
#      'author': {'email': '58341448+kam1n0@users.noreply.github.com',
#       'name': 'kam1n0'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kam1n0/suid-abuse-bash-debug/commits/6f246d39f864904134b39abf8d813e9aa7ea27e3'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:31:38Z'},
#  {'id': '12486622422',
#   'type': 'DeleteEvent',
#   'actor': {'id': 23636124,
#    'login': 'cschanaj',
#    'display_login': 'cschanaj',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cschanaj',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23636124?'},
#   'repo': {'id': 75582588,
#    'name': 'cschanaj/https-everywhere',
#    'url': 'https://api.github.com/repos/cschanaj/https-everywhere'},
#   'payload': {'ref': 'watsons-com-hk',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-31T03:31:37Z'},
#  {'id': '12486622416',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 255707065,
#    'name': 'jorgebg/airquality',
#    'url': 'https://api.github.com/repos/jorgebg/airquality'},
#   'payload': {'push_id': 5153507346,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/state',
#    'head': 'bead63c2f8e47896e5482354844ccb50f5ac432c',
#    'before': '192fc1b55af5750b2b21f922fb724613c38347dd',
#    'commits': [{'sha': 'bead63c2f8e47896e5482354844ccb50f5ac432c',
#      'author': {'email': 'airquality@jorgebg.com', 'name': 'Air Quality Bot'},
#      'message': '10 messages found from 2020-05-31 03:30:00 to 2020-05-31 03:31:30',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jorgebg/airquality/commits/bead63c2f8e47896e5482354844ccb50f5ac432c'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:31:37Z'},
#  {'id': '12486622415',
#   'type': 'PushEvent',
#   'actor': {'id': 38885565,
#    'login': 'Lorraine318',
#    'display_login': 'Lorraine318',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Lorraine318',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38885565?'},
#   'repo': {'id': 264163792,
#    'name': 'Lorraine318/kafka2.0.0',
#    'url': 'https://api.github.com/repos/Lorraine318/kafka2.0.0'},
#   'payload': {'push_id': 5153507344,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '391d647d389d6c2c694a086d73dedd31dda6a91a',
#    'before': 'a2aef53c5b84135c3c4ee0899ae31b8e56799feb',
#    'commits': [{'sha': '391d647d389d6c2c694a086d73dedd31dda6a91a',
#      'author': {'email': 'Yuni725621', 'name': 'Lorraine318'},
#      'message': 'commit KafkaController about topic,broker...handler',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Lorraine318/kafka2.0.0/commits/391d647d389d6c2c694a086d73dedd31dda6a91a'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:31:37Z'},
#  {'id': '12486622414',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 20407524,
#    'login': 'k8s-ci-robot',
#    'display_login': 'k8s-ci-robot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/k8s-ci-robot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20407524?'},
#   'repo': {'id': 57912964,
#    'name': 'kubernetes/enhancements',
#    'url': 'https://api.github.com/repos/kubernetes/enhancements'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/kubernetes/enhancements/issues/1834',
#     'repository_url': 'https://api.github.com/repos/kubernetes/enhancements',
#     'labels_url': 'https://api.github.com/repos/kubernetes/enhancements/issues/1834/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/kubernetes/enhancements/issues/1834/comments',
#     'events_url': 'https://api.github.com/repos/kubernetes/enhancements/issues/1834/events',
#     'html_url': 'https://github.com/kubernetes/enhancements/pull/1834',
#     'id': 627883435,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDI1NTU0OTMz',
#     'number': 1834,
#     'title': 'modify the error url of kustomize',
#     'user': {'login': 'timyinshi',
#      'id': 35130894,
#      'node_id': 'MDQ6VXNlcjM1MTMwODk0',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/35130894?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/timyinshi',
#      'html_url': 'https://github.com/timyinshi',
#      'followers_url': 'https://api.github.com/users/timyinshi/followers',
#      'following_url': 'https://api.github.com/users/timyinshi/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/timyinshi/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/timyinshi/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/timyinshi/subscriptions',
#      'organizations_url': 'https://api.github.com/users/timyinshi/orgs',
#      'repos_url': 'https://api.github.com/users/timyinshi/repos',
#      'events_url': 'https://api.github.com/users/timyinshi/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/timyinshi/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 495183842,
#       'node_id': 'MDU6TGFiZWw0OTUxODM4NDI=',
#       'url': 'https://api.github.com/repos/kubernetes/enhancements/labels/cncf-cla:%20yes',
#       'name': 'cncf-cla: yes',
#       'color': 'bfe5bf',
#       'default': False,
#       'description': "Indicates the PR's author has signed the CNCF CLA."},
#      {'id': 1076074044,
#       'node_id': 'MDU6TGFiZWwxMDc2MDc0MDQ0',
#       'url': 'https://api.github.com/repos/kubernetes/enhancements/labels/kind/kep',
#       'name': 'kind/kep',
#       'color': 'cc99ff',
#       'default': False,
#       'description': 'Categorizes KEP tracking issues and PRs modifying the KEP directory'},
#      {'id': 664407886,
#       'node_id': 'MDU6TGFiZWw2NjQ0MDc4ODY=',
#       'url': 'https://api.github.com/repos/kubernetes/enhancements/labels/sig/architecture',
#       'name': 'sig/architecture',
#       'color': 'd2b48c',
#       'default': False,
#       'description': 'Categorizes an issue or PR as relevant to sig-architecture.'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-05-31T03:31:24Z',
#     'updated_at': '2020-05-31T03:31:37Z',
#     'closed_at': None,
#     'author_association': 'MEMBER',
#     'pull_request': {'url': 'https://api.github.com/repos/kubernetes/enhancements/pulls/1834',
#      'html_url': 'https://github.com/kubernetes/enhancements/pull/1834',
#      'diff_url': 'https://github.com/kubernetes/enhancements/pull/1834.diff',
#      'patch_url': 'https://github.com/kubernetes/enhancements/pull/1834.patch'},
#     'body': 'the error url is: https://github.com/kubernetes-sigs/kustomize/tree/master/pkg/target\r\nthe right url is: https://github.com/kubernetes-sigs/kustomize/tree/master/api/internal/target'},
#    'comment': {'url': 'https://api.github.com/repos/kubernetes/enhancements/issues/comments/636415381',
#     'html_url': 'https://github.com/kubernetes/enhancements/pull/1834#issuecomment-636415381',
#     'issue_url': 'https://api.github.com/repos/kubernetes/enhancements/issues/1834',
#     'id': 636415381,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDYzNjQxNTM4MQ==',
#     'user': {'login': 'k8s-ci-robot',
#      'id': 20407524,
#      'node_id': 'MDQ6VXNlcjIwNDA3NTI0',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/20407524?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/k8s-ci-robot',
#      'html_url': 'https://github.com/k8s-ci-robot',
#      'followers_url': 'https://api.github.com/users/k8s-ci-robot/followers',
#      'following_url': 'https://api.github.com/users/k8s-ci-robot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/k8s-ci-robot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/k8s-ci-robot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/k8s-ci-robot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/k8s-ci-robot/orgs',
#      'repos_url': 'https://api.github.com/users/k8s-ci-robot/repos',
#      'events_url': 'https://api.github.com/users/k8s-ci-robot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/k8s-ci-robot/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-05-31T03:31:37Z',
#     'updated_at': '2020-05-31T03:31:37Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': '[APPROVALNOTIFIER] This PR is **NOT APPROVED**\n\nThis pull-request has been approved by: *<a href="https://github.com/kubernetes/enhancements/pull/1834#" title="Author self-approved">timyinshi</a>*\nTo complete the [pull request process](https://git.k8s.io/community/contributors/guide/owners.md#the-code-review-process), please assign **soltysh**\nYou can assign the PR to them by writing `/assign @soltysh` in a comment when ready.\n\nThe full list of commands accepted by this bot can be found [here](https://go.k8s.io/bot-commands?repo=kubernetes%2Fenhancements).\n\n<details open>\nNeeds approval from an approver in each of these files:\n\n- **[keps/sig-cli/OWNERS](https://github.com/kubernetes/enhancements/blob/master/keps/sig-cli/OWNERS)**\n\nApprovers can indicate their approval by writing `/approve` in a comment\nApprovers can cancel approval by writing `/approve cancel` in a comment\n</details>\n<!-- META={"approvers":["soltysh"]} -->'}},
#   'public': True,
#   'created_at': '2020-05-31T03:31:37Z',
#   'org': {'id': 13629408,
#    'login': 'kubernetes',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/kubernetes',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13629408?'}},
#  {'id': '12486622404',
#   'type': 'PushEvent',
#   'actor': {'id': 25531308,
#    'login': 'va1entei',
#    'display_login': 'va1entei',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/va1entei',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25531308?'},
#   'repo': {'id': 247657035,
#    'name': 'va1entei/retdec',
#    'url': 'https://api.github.com/repos/va1entei/retdec'},
#   'payload': {'push_id': 5153507339,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '31d86fd504e3e84ffd7a65c4df95948b46695616',
#    'before': 'fa2823cdcd0db51468490aa1f87ae4e66657b249',
#    'commits': [{'sha': '31d86fd504e3e84ffd7a65c4df95948b46695616',
#      'author': {'email': 'va1entei@github.com', 'name': 'va1entei'},
#      'message': 'works commit rect2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/va1entei/retdec/commits/31d86fd504e3e84ffd7a65c4df95948b46695616'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:31:37Z'},
#  {'id': '12486622406',
#   'type': 'WatchEvent',
#   'actor': {'id': 7246841,
#    'login': 'xianping-li',
#    'display_login': 'xianping-li',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xianping-li',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7246841?'},
#   'repo': {'id': 62469870,
#    'name': 'adw96/breakaway',
#    'url': 'https://api.github.com/repos/adw96/breakaway'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-05-31T03:31:37Z'},
#  {'id': '12486622407',
#   'type': 'CreateEvent',
#   'actor': {'id': 21216122,
#    'login': 'KouichiSano',
#    'display_login': 'KouichiSano',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/KouichiSano',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21216122?'},
#   'repo': {'id': 268201684,
#    'name': 'KouichiSano/review_shop',
#    'url': 'https://api.github.com/repos/KouichiSano/review_shop'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
# ...
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/58576711?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Techopath',
#        'html_url': 'https://github.com/Techopath',
#        'followers_url': 'https://api.github.com/users/Techopath/followers',
#        'following_url': 'https://api.github.com/users/Techopath/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Techopath/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Techopath/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Techopath/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Techopath/orgs',
#        'repos_url': 'https://api.github.com/users/Techopath/repos',
#        'events_url': 'https://api.github.com/users/Techopath/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Techopath/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Techopath/zerobank',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/Techopath/zerobank',
#       'forks_url': 'https://api.github.com/repos/Techopath/zerobank/forks',
#       'keys_url': 'https://api.github.com/repos/Techopath/zerobank/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Techopath/zerobank/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Techopath/zerobank/teams',
#       'hooks_url': 'https://api.github.com/repos/Techopath/zerobank/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Techopath/zerobank/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Techopath/zerobank/events',
#       'assignees_url': 'https://api.github.com/repos/Techopath/zerobank/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Techopath/zerobank/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Techopath/zerobank/tags',
#       'blobs_url': 'https://api.github.com/repos/Techopath/zerobank/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Techopath/zerobank/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Techopath/zerobank/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Techopath/zerobank/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Techopath/zerobank/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Techopath/zerobank/languages',
#       'stargazers_url': 'https://api.github.com/repos/Techopath/zerobank/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Techopath/zerobank/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Techopath/zerobank/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Techopath/zerobank/subscription',
#       'commits_url': 'https://api.github.com/repos/Techopath/zerobank/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Techopath/zerobank/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Techopath/zerobank/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Techopath/zerobank/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Techopath/zerobank/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Techopath/zerobank/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Techopath/zerobank/merges',
#       'archive_url': 'https://api.github.com/repos/Techopath/zerobank/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Techopath/zerobank/downloads',
#       'issues_url': 'https://api.github.com/repos/Techopath/zerobank/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Techopath/zerobank/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Techopath/zerobank/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Techopath/zerobank/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Techopath/zerobank/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Techopath/zerobank/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Techopath/zerobank/deployments',
#       'created_at': '2020-05-30T04:09:50Z',
#       'updated_at': '2020-05-30T06:31:00Z',
#       'pushed_at': '2020-05-31T03:29:04Z',
#       'git_url': 'git://github.com/Techopath/zerobank.git',
#       'ssh_url': 'git@github.com:Techopath/zerobank.git',
#       'clone_url': 'https://github.com/Techopath/zerobank.git',
#       'svn_url': 'https://github.com/Techopath/zerobank',
#       'homepage': None,
#       'size': 23,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Java',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'Techopath:master',
#      'ref': 'master',
#      'sha': 'b568f65d68ef79cd49a39b4340561d9b76ce9a97',
#      'user': {'login': 'Techopath',
#       'id': 58576711,
#       'node_id': 'MDQ6VXNlcjU4NTc2NzEx',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/58576711?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Techopath',
#       'html_url': 'https://github.com/Techopath',
#       'followers_url': 'https://api.github.com/users/Techopath/followers',
#       'following_url': 'https://api.github.com/users/Techopath/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Techopath/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Techopath/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Techopath/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Techopath/orgs',
#       'repos_url': 'https://api.github.com/users/Techopath/repos',
#       'events_url': 'https://api.github.com/users/Techopath/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Techopath/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 268006874,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNjgwMDY4NzQ=',
#       'name': 'zerobank',
#       'full_name': 'Techopath/zerobank',
#       'private': False,
#       'owner': {'login': 'Techopath',
#        'id': 58576711,
#        'node_id': 'MDQ6VXNlcjU4NTc2NzEx',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/58576711?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Techopath',
#        'html_url': 'https://github.com/Techopath',
#        'followers_url': 'https://api.github.com/users/Techopath/followers',
#        'following_url': 'https://api.github.com/users/Techopath/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Techopath/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Techopath/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Techopath/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Techopath/orgs',
#        'repos_url': 'https://api.github.com/users/Techopath/repos',
#        'events_url': 'https://api.github.com/users/Techopath/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Techopath/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Techopath/zerobank',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/Techopath/zerobank',
#       'forks_url': 'https://api.github.com/repos/Techopath/zerobank/forks',
#       'keys_url': 'https://api.github.com/repos/Techopath/zerobank/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Techopath/zerobank/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Techopath/zerobank/teams',
#       'hooks_url': 'https://api.github.com/repos/Techopath/zerobank/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Techopath/zerobank/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Techopath/zerobank/events',
#       'assignees_url': 'https://api.github.com/repos/Techopath/zerobank/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Techopath/zerobank/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Techopath/zerobank/tags',
#       'blobs_url': 'https://api.github.com/repos/Techopath/zerobank/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Techopath/zerobank/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Techopath/zerobank/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Techopath/zerobank/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Techopath/zerobank/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Techopath/zerobank/languages',
#       'stargazers_url': 'https://api.github.com/repos/Techopath/zerobank/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Techopath/zerobank/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Techopath/zerobank/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Techopath/zerobank/subscription',
#       'commits_url': 'https://api.github.com/repos/Techopath/zerobank/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Techopath/zerobank/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Techopath/zerobank/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Techopath/zerobank/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Techopath/zerobank/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Techopath/zerobank/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Techopath/zerobank/merges',
#       'archive_url': 'https://api.github.com/repos/Techopath/zerobank/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Techopath/zerobank/downloads',
#       'issues_url': 'https://api.github.com/repos/Techopath/zerobank/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Techopath/zerobank/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Techopath/zerobank/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Techopath/zerobank/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Techopath/zerobank/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Techopath/zerobank/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Techopath/zerobank/deployments',
#       'created_at': '2020-05-30T04:09:50Z',
#       'updated_at': '2020-05-30T06:31:00Z',
#       'pushed_at': '2020-05-31T03:29:04Z',
#       'git_url': 'git://github.com/Techopath/zerobank.git',
#       'ssh_url': 'git@github.com:Techopath/zerobank.git',
#       'clone_url': 'https://github.com/Techopath/zerobank.git',
#       'svn_url': 'https://github.com/Techopath/zerobank',
#       'homepage': None,
#       'size': 23,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Java',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Techopath/zerobank/pulls/2'},
#      'html': {'href': 'https://github.com/Techopath/zerobank/pull/2'},
#      'issue': {'href': 'https://api.github.com/repos/Techopath/zerobank/issues/2'},
#      'comments': {'href': 'https://api.github.com/repos/Techopath/zerobank/issues/2/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Techopath/zerobank/pulls/2/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Techopath/zerobank/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Techopath/zerobank/pulls/2/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Techopath/zerobank/statuses/c6d2480775cbd39d700726377db1eb093acda6f8'}},
#     'author_association': 'COLLABORATOR',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 2,
#     'additions': 26,
#     'deletions': 10,
#     'changed_files': 11}},
#   'public': True,
#   'created_at': '2020-05-31T03:31:37Z'},
#  {'id': '12486622390',
#   'type': 'CreateEvent',
#   'actor': {'id': 18558130,
#    'login': 'elihschiff',
#    'display_login': 'elihschiff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/elihschiff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18558130?'},
#   'repo': {'id': 6190712,
#    'name': 'RPI-UPE/rpi-upe.github.com',
#    'url': 'https://api.github.com/repos/RPI-UPE/rpi-upe.github.com'},
#   'payload': {'ref': 'committee_updates',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': "RPI UPE's website",
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-31T03:31:37Z',
#   'org': {'id': 1698775,
#    'login': 'RPI-UPE',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/RPI-UPE',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1698775?'}},
#  {'id': '12486622384',
#   'type': 'PushEvent',
#   'actor': {'id': 59677854,
#    'login': 'RHYDYO',
#    'display_login': 'RHYDYO',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RHYDYO',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59677854?'},
#   'repo': {'id': 232721657,
#    'name': 'RHYDYO/repository2',
#    'url': 'https://api.github.com/repos/RHYDYO/repository2'},
#   'payload': {'push_id': 5153507324,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3d242802cb6540fdfef631272c816b29bc25eee1',
#    'before': '0272c6d1d8745fa0d3160b492e737750a40f5ea3',
#    'commits': [{'sha': '3d242802cb6540fdfef631272c816b29bc25eee1',
#      'author': {'email': '59677854+RHYDYO@users.noreply.github.com',
#       'name': 'RHYDYO'},
#      'message': 'bossDB',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/RHYDYO/repository2/commits/3d242802cb6540fdfef631272c816b29bc25eee1'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:31:37Z'},
#  {'id': '12486622386',
#   'type': 'PushEvent',
#   'actor': {'id': 45794033,
#    'login': 'eesantiago',
#    'display_login': 'eesantiago',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eesantiago',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45794033?'},
#   'repo': {'id': 236624464,
#    'name': 'eesantiago/pentest_checklists',
#    'url': 'https://api.github.com/repos/eesantiago/pentest_checklists'},
#   'payload': {'push_id': 5153507320,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd811e8e1fedbe2aba146d1f4ce1944ed9eff97d1',
#    'before': '6703b3fef81c44e05fc0c856fcf852f4b1dcc09a',
#    'commits': [{'sha': 'd811e8e1fedbe2aba146d1f4ce1944ed9eff97d1',
#      'author': {'email': '45794033+eesantiago@users.noreply.github.com',
#       'name': 'Emilio Santiago'},
#      'message': 'Update Steganography.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eesantiago/pentest_checklists/commits/d811e8e1fedbe2aba146d1f4ce1944ed9eff97d1'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:31:37Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
# 個人備註:
#106各鄉鎮市區人口密度
#https://od.moi.gov.tw/api/v1/rest/datastore/301000000A-000605-040
#TEXT方法
#==================================================================

r1 = requests.get('https://api.github.com/events')

r1.text
# Out:
# '[{"id":"12486662041","type":"PushEvent","actor":{"id":53884867,"login":"donghangwu","display_login":"donghangwu","gravatar_id":"","url":"https://api.github.com/users/donghangwu","avatar_url":"https://avatars.githubusercontent.com/u/53884867?"},"repo":{"id":265029118,"name":"donghangwu/leetcode","url":"https://api.github.com/repos/donghangwu/leetcode"},"payload":{"push_id":5153533216,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"3e3b2f159f815999f91e3f1f9bccde5b4b824b07","before":"494bc0c3087adf71befb3a2595e67cc385114824","commits":[{"sha":"3e3b2f159f815999f91e3f1f9bccde5b4b824b07","author":{"email":"53884867+donghangwu@users.noreply.github.com","name":"jonny"},"message":"Create 1392. Longest Happy Prefix","distinct":true,"url":"https://api.github.com/repos/donghangwu/leetcode/commits/3e3b2f159f815999f91e3f1f9bccde5b4b824b07"}]},"public":true,"created_at":"2020-05-31T03:50:36Z"},{"id":"12486662035","type":"PushEvent","actor":{"id":28620881,"login":"wzyonggege","display_login":"wzyonggege","gravatar_id":"","url":"https://api.github.com/users/wzyonggege","avatar_url":"https://avatars.githubusercontent.com/u/28620881?"},"repo":{"id":267830138,"name":"wzyonggege/goutils","url":"https://api.github.com/repos/wzyonggege/goutils"},"payload":{"push_id":5153533211,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"062727b1ff66761e8e086d8ee2123f9c4e1a5d63","before":"8f35e8afca60d98f0b674782a51203202bc9ed93","commits":[{"sha":"062727b1ff66761e8e086d8ee2123f9c4e1a5d63","author":{"email":"jamwong994@gmail.com","name":"jam"},"message":"add choke","distinct":true,"url":"https://api.github.com/repos/wzyonggege/goutils/commits/062727b1ff66761e8e086d8ee2123f9c4e1a5d63"}]},"public":true,"created_at":"2020-05-31T03:50:36Z"},{"id":"12486662034","type":"PushEvent","actor":{"id":59679752,"login":"shangwoa","display_login":"shangwoa","gravatar_id":"","url":"https://api.github.com/users/shangwoa","avatar_url":"https://avatars.githubusercontent.com/u/59679752?"},"repo":{"id":268193932,"name":"shangwoa/ab6019","url":"https://api.github.com/repos/shangwoa/ab6019"},"payload":{"push_id":5153533210,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"1bf54c8309a76ade47ce6b7714b374179ff83b48","before":"d6601dd0cb25db92e916df13470342c50337e359","commits":[{"sha":"1bf54c8309a76ade47ce6b7714b374179ff83b48","author":{"email":"shangwoa@gmail.com","name":"shangwoa"},"message":"dA0rxBmn","distinct":true,"url":"https://api.github.com/repos/shangwoa/ab6019/commits/1bf54c8309a76ade47ce6b7714b374179ff83b48"}]},"public":true,"created_at":"2020-05-31T03:50:36Z"},{"id":"12486662033","type":"PushEvent","actor":{"id":63510547,"login":"barbarasw","display_login":"barbarasw","gravatar_id":"","url":"https://api.github.com/users/barbarasw","avatar_url":"https://avatars.githubusercontent.com/u/63510547?"},"repo":{"id":268203323,"name":"barbarasw/Homework5-Pymaceuticals","url":"https://api.github.com/repos/barbarasw/Homework5-Pymaceuticals"},"payload":{"push_id":5153533209,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"7cf821ad107a69bfb90298f87e81824f67b1b3e7","before":"8cd0aabe610d15c17305c64c052db53a6058a84b","commits":[{"sha":"7cf821ad107a69bfb90298f87e81824f67b1b3e7","author":{"email":"63510547+barbarasw@users.noreply.github.com","name":"barbarasw"},"message":"Add files via upload","distinct":true,"url":"https://api.github.com/repos/barbarasw/Homework5-Pymaceuticals/commits/7cf821ad107a69bfb90298f87e81824f67b1b3e7"}]},"public":true,"created_at":"2020-05-31T03:50:36Z"},{"id":"12486662031","type":"CreateEvent","actor":{"id":65860937,"login":"haritha2169","display_login":"haritha2169","gravatar_id":"","url":"https://api.github.com/users/haritha2169","avatar_url":"https://avatars.githubusercontent.com/u/65860937?"},"repo":{"id":268204613,"name":"haritha2169/code","url":"https://api.github.com/repos/haritha2169/code"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":null,"pusher_type":"user"},"public" ...

# %%
json.loads(r1.text)
# Out:
# [{'id': '12486662041',
#   'type': 'PushEvent',
#   'actor': {'id': 53884867,
#    'login': 'donghangwu',
#    'display_login': 'donghangwu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/donghangwu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53884867?'},
#   'repo': {'id': 265029118,
#    'name': 'donghangwu/leetcode',
#    'url': 'https://api.github.com/repos/donghangwu/leetcode'},
#   'payload': {'push_id': 5153533216,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3e3b2f159f815999f91e3f1f9bccde5b4b824b07',
#    'before': '494bc0c3087adf71befb3a2595e67cc385114824',
#    'commits': [{'sha': '3e3b2f159f815999f91e3f1f9bccde5b4b824b07',
#      'author': {'email': '53884867+donghangwu@users.noreply.github.com',
#       'name': 'jonny'},
#      'message': 'Create 1392. Longest Happy Prefix',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/donghangwu/leetcode/commits/3e3b2f159f815999f91e3f1f9bccde5b4b824b07'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:50:36Z'},
#  {'id': '12486662035',
#   'type': 'PushEvent',
#   'actor': {'id': 28620881,
#    'login': 'wzyonggege',
#    'display_login': 'wzyonggege',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wzyonggege',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28620881?'},
#   'repo': {'id': 267830138,
#    'name': 'wzyonggege/goutils',
#    'url': 'https://api.github.com/repos/wzyonggege/goutils'},
#   'payload': {'push_id': 5153533211,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '062727b1ff66761e8e086d8ee2123f9c4e1a5d63',
#    'before': '8f35e8afca60d98f0b674782a51203202bc9ed93',
#    'commits': [{'sha': '062727b1ff66761e8e086d8ee2123f9c4e1a5d63',
#      'author': {'email': 'jamwong994@gmail.com', 'name': 'jam'},
#      'message': 'add choke',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wzyonggege/goutils/commits/062727b1ff66761e8e086d8ee2123f9c4e1a5d63'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:50:36Z'},
#  {'id': '12486662034',
#   'type': 'PushEvent',
#   'actor': {'id': 59679752,
#    'login': 'shangwoa',
#    'display_login': 'shangwoa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shangwoa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59679752?'},
#   'repo': {'id': 268193932,
#    'name': 'shangwoa/ab6019',
#    'url': 'https://api.github.com/repos/shangwoa/ab6019'},
#   'payload': {'push_id': 5153533210,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1bf54c8309a76ade47ce6b7714b374179ff83b48',
#    'before': 'd6601dd0cb25db92e916df13470342c50337e359',
#    'commits': [{'sha': '1bf54c8309a76ade47ce6b7714b374179ff83b48',
#      'author': {'email': 'shangwoa@gmail.com', 'name': 'shangwoa'},
#      'message': 'dA0rxBmn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shangwoa/ab6019/commits/1bf54c8309a76ade47ce6b7714b374179ff83b48'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:50:36Z'},
#  {'id': '12486662033',
#   'type': 'PushEvent',
#   'actor': {'id': 63510547,
#    'login': 'barbarasw',
#    'display_login': 'barbarasw',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/barbarasw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63510547?'},
#   'repo': {'id': 268203323,
#    'name': 'barbarasw/Homework5-Pymaceuticals',
#    'url': 'https://api.github.com/repos/barbarasw/Homework5-Pymaceuticals'},
#   'payload': {'push_id': 5153533209,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7cf821ad107a69bfb90298f87e81824f67b1b3e7',
#    'before': '8cd0aabe610d15c17305c64c052db53a6058a84b',
#    'commits': [{'sha': '7cf821ad107a69bfb90298f87e81824f67b1b3e7',
#      'author': {'email': '63510547+barbarasw@users.noreply.github.com',
#       'name': 'barbarasw'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/barbarasw/Homework5-Pymaceuticals/commits/7cf821ad107a69bfb90298f87e81824f67b1b3e7'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:50:36Z'},
#  {'id': '12486662031',
#   'type': 'CreateEvent',
#   'actor': {'id': 65860937,
#    'login': 'haritha2169',
#    'display_login': 'haritha2169',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/haritha2169',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65860937?'},
#   'repo': {'id': 268204613,
#    'name': 'haritha2169/code',
#    'url': 'https://api.github.com/repos/haritha2169/code'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-31T03:50:36Z'},
#  {'id': '12486662025',
#   'type': 'PushEvent',
#   'actor': {'id': 57737695,
#    'login': 'anyutong2019012625',
#    'display_login': 'anyutong2019012625',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/anyutong2019012625',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57737695?'},
#   'repo': {'id': 268200398,
#    'name': 'anyutong2019012625/web',
#    'url': 'https://api.github.com/repos/anyutong2019012625/web'},
#   'payload': {'push_id': 5153533206,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ec731d2c5aea172bcda1eaa01106e21aea7f0cf3',
#    'before': '1a5cf9d0d44c89405aea63f076c81873e7556fa9',
#    'commits': [{'sha': 'ec731d2c5aea172bcda1eaa01106e21aea7f0cf3',
#      'author': {'email': '57737695+anyutong2019012625@users.noreply.github.com',
#       'name': 'anyutong2019012625'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/anyutong2019012625/web/commits/ec731d2c5aea172bcda1eaa01106e21aea7f0cf3'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:50:36Z'},
#  {'id': '12486662026',
#   'type': 'PushEvent',
#   'actor': {'id': 66061846,
#    'login': 'ososstech',
#    'display_login': 'ososstech',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ososstech',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66061846?'},
#   'repo': {'id': 268160911,
#    'name': 'ososstech/ososstech',
#    'url': 'https://api.github.com/repos/ososstech/ososstech'},
#   'payload': {'push_id': 5153533205,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3521b718a7ea21285b9c0debc2658c7ba3bc1e7f',
#    'before': '55c85bf94bc14f7238a8cffbfd9f8b48949d82cd',
#    'commits': [{'sha': '3521b718a7ea21285b9c0debc2658c7ba3bc1e7f',
#      'author': {'email': '66061846+ososstech@users.noreply.github.com',
#       'name': 'ososstech'},
#      'message': 'Initial Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ososstech/ososstech/commits/3521b718a7ea21285b9c0debc2658c7ba3bc1e7f'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:50:36Z'},
#  {'id': '12486662028',
#   'type': 'DeleteEvent',
#   'actor': {'id': 5652550,
#    'login': 'sumeshm',
#    'display_login': 'sumeshm',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sumeshm',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5652550?'},
#   'repo': {'id': 116668794,
#    'name': 'sumeshm/Android',
#    'url': 'https://api.github.com/repos/sumeshm/Android'},
#   'payload': {'ref': 'service_dialog',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-31T03:50:36Z'},
#  {'id': '12486662024',
#   'type': 'PushEvent',
#   'actor': {'id': 43549877,
#    'login': 'phu-n-tran',
#    'display_login': 'phu-n-tran',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phu-n-tran',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43549877?'},
#   'repo': {'id': 260779048,
#    'name': 'phu-n-tran/LeetCode',
#    'url': 'https://api.github.com/repos/phu-n-tran/LeetCode'},
#   'payload': {'push_id': 5153533193,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ca49bd3cc890e9c0d9b62c2ddfab0329ca8a855e',
#    'before': 'cc70dfb1e13ff0d3217f9aafa7d91c39fa3158ce',
#    'commits': [{'sha': 'ca49bd3cc890e9c0d9b62c2ddfab0329ca8a855e',
#      'author': {'email': 'andytran1997@gmail.com', 'name': 'Phu Tran'},
#      'message': 'Rename 5_30_KClosestPoints to 5_30_KClosestPoints.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/phu-n-tran/LeetCode/commits/ca49bd3cc890e9c0d9b62c2ddfab0329ca8a855e'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:50:36Z'},
#  {'id': '12486662022',
#   'type': 'PushEvent',
#   'actor': {'id': 54263129,
#    'login': 'lili-li',
#    'display_login': 'lili-li',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lili-li',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54263129?'},
#   'repo': {'id': 234872245,
#    'name': 'lili-li/VOC-format-2007',
#    'url': 'https://api.github.com/repos/lili-li/VOC-format-2007'},
#   'payload': {'push_id': 5153533201,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '5cd2cf2126bb0d5a9aead530824cab109d9e2537',
#    'before': '7179eca645e869a68d04b7144afb125456128522',
#    'commits': [{'sha': '5cd2cf2126bb0d5a9aead530824cab109d9e2537',
#      'author': {'email': '905572538@qq.com', 'name': 'lili-li'},
#      'message': 'create the txt.doc',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lili-li/VOC-format-2007/commits/5cd2cf2126bb0d5a9aead530824cab109d9e2537'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:50:36Z'},
#  {'id': '12486662015',
#   'type': 'PushEvent',
#   'actor': {'id': 5591821,
#    'login': 'mblue9',
#    'display_login': 'mblue9',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mblue9',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5591821?'},
#   'repo': {'id': 244227919,
#    'name': 'stemangiola/bioc_2020_tidytranscriptomics',
#    'url': 'https://api.github.com/repos/stemangiola/bioc_2020_tidytranscriptomics'},
#   'payload': {'push_id': 5153533200,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/few-edits',
#    'head': 'f27d275ac260e2a6299cc248cdee09ccb801ca39',
#    'before': '81b399947608355f0d6da3cb80f53adc9b761742',
#    'commits': [{'sha': 'f27d275ac260e2a6299cc248cdee09ccb801ca39',
#      'author': {'email': 'maria.doyle@petermac.org', 'name': 'mblue9'},
#      'message': 'Update vignettes/tidytranscriptomics.Rmd',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/stemangiola/bioc_2020_tidytranscriptomics/commits/f27d275ac260e2a6299cc248cdee09ccb801ca39'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:50:36Z'},
#  {'id': '12486661997',
#   'type': 'PushEvent',
#   'actor': {'id': 51150235,
#    'login': 'opstest2',
#    'display_login': 'opstest2',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/opstest2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51150235?'},
#   'repo': {'id': 268203068,
#    'name': 'MicrosoftDocs/E2E_ServiceAccount2_Test_PPE',
#    'url': 'https://api.github.com/repos/MicrosoftDocs/E2E_ServiceAccount2_Test_PPE'},
#   'payload': {'push_id': 5153533187,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/test',
#    'head': '602a2c8de7ac136e9bdbdcb0da87b7b6473673b2',
#    'before': '34b59b3f24b552c2d4a3934b48314b7de47d0c65',
#    'commits': [{'sha': '602a2c8de7ac136e9bdbdcb0da87b7b6473673b2',
#      'author': {'email': '51150235+opstest2@users.noreply.github.com',
#       'name': 'opstest2'},
#      'message': 'Update index.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MicrosoftDocs/E2E_ServiceAccount2_Test_PPE/commits/602a2c8de7ac136e9bdbdcb0da87b7b6473673b2'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:50:35Z',
#   'org': {'id': 22479449,
#    'login': 'MicrosoftDocs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/MicrosoftDocs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22479449?'}},
#  {'id': '12486662013',
#   'type': 'DeleteEvent',
#   'actor': {'id': 5652550,
#    'login': 'sumeshm',
#    'display_login': 'sumeshm',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sumeshm',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5652550?'},
#   'repo': {'id': 116668794,
#    'name': 'sumeshm/Android',
#    'url': 'https://api.github.com/repos/sumeshm/Android'},
#   'payload': {'ref': 'service_activity',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-31T03:50:36Z'},
#  {'id': '12486662010',
#   'type': 'PushEvent',
#   'actor': {'id': 65939591,
#    'login': 'Astrazo',
#    'display_login': 'Astrazo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Astrazo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65939591?'},
#   'repo': {'id': 266956191,
#    'name': 'Astrazo/rivescriptbot',
#    'url': 'https://api.github.com/repos/Astrazo/rivescriptbot'},
#   'payload': {'push_id': 5153533197,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '92b8820ab040ebc4bf4f49f60a8367f28d5b1595',
#    'before': 'da9d2eaeefb8a6fe5310e2f7b76a762593e9237c',
#    'commits': [{'sha': '92b8820ab040ebc4bf4f49f60a8367f28d5b1595',
#      'author': {'email': '65939591+Astrazo@users.noreply.github.com',
#       'name': 'Joshua'},
#      'message': 'Update myself.rive',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Astrazo/rivescriptbot/commits/92b8820ab040ebc4bf4f49f60a8367f28d5b1595'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:50:36Z'},
#  {'id': '12486662005',
#   'type': 'PushEvent',
#   'actor': {'id': 25531308,
#    'login': 'va1entei',
#    'display_login': 'va1entei',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/va1entei',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25531308?'},
#   'repo': {'id': 247657035,
#    'name': 'va1entei/retdec',
#    'url': 'https://api.github.com/repos/va1entei/retdec'},
#   'payload': {'push_id': 5153533191,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b547c8c221303969730e8c2712a64f7be7a31de2',
#    'before': 'ef8b68fd65bc54e3cfaaafe4703bedaa03f499aa',
#    'commits': [{'sha': 'b547c8c221303969730e8c2712a64f7be7a31de2',
#      'author': {'email': 'va1entei@github.com', 'name': 'va1entei'},
#      'message': 'works commit rect2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/va1entei/retdec/commits/b547c8c221303969730e8c2712a64f7be7a31de2'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:50:35Z'},
#  {'id': '12486662007',
#   'type': 'IssuesEvent',
#   'actor': {'id': 18039288,
#    'login': 'sapdocsqa',
#    'display_login': 'sapdocsqa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sapdocsqa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18039288?'},
#   'repo': {'id': 265179759,
#    'name': 'stepanfirsov/tutorials',
#    'url': 'https://api.github.com/repos/stepanfirsov/tutorials'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/stepanfirsov/tutorials/issues/4489',
#     'repository_url': 'https://api.github.com/repos/stepanfirsov/tutorials',
#     'labels_url': 'https://api.github.com/repos/stepanfirsov/tutorials/issues/4489/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/stepanfirsov/tutorials/issues/4489/comments',
#     'events_url': 'https://api.github.com/repos/stepanfirsov/tutorials/issues/4489/events',
#     'html_url': 'https://github.com/stepanfirsov/tutorials/issues/4489',
#     'id': 627885374,
#     'node_id': 'MDU6SXNzdWU2Mjc4ODUzNzQ=',
#     'number': 4489,
#     'title': '. QA GREEN',
#     'user': {'login': 'sapdocsqa',
#      'id': 18039288,
#      'node_id': 'MDQ6VXNlcjE4MDM5Mjg4',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/18039288?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/sapdocsqa',
#      'html_url': 'https://github.com/sapdocsqa',
#      'followers_url': 'https://api.github.com/users/sapdocsqa/followers',
#      'following_url': 'https://api.github.com/users/sapdocsqa/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/sapdocsqa/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/sapdocsqa/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/sapdocsqa/subscriptions',
#      'organizations_url': 'https://api.github.com/users/sapdocsqa/orgs',
#      'repos_url': 'https://api.github.com/users/sapdocsqa/repos',
#      'events_url': 'https://api.github.com/users/sapdocsqa/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/sapdocsqa/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-05-31T03:50:35Z',
#     'updated_at': '2020-05-31T03:50:35Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': 'Tutorial issue found: [https://github.com/StepanFirsov/tutorials/blob/master/tutorials/AS_10/license.md](https://github.com/StepanFirsov/tutorials/blob/master/tutorials/AS_10/license.md) contains invalid tags. Even though your tutorial was created, the invalid tags listed below were disregarded. Please double-check the following tags:\n- tutorial:products:/content/73555000100700000761\n\n Affected server: QA GREEN'}},
#   'public': True,
#   'created_at': '2020-05-31T03:50:35Z'},
#  {'id': '12486662003',
#   'type': 'WatchEvent',
#   'actor': {'id': 59506149,
#    'login': 'Packoc',
#    'display_login': 'Packoc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Packoc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59506149?'},
#   'repo': {'id': 266702263,
#    'name': 'pshihn/rough-notation',
#    'url': 'https://api.github.com/repos/pshihn/rough-notation'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-05-31T03:50:35Z'},
#  {'id': '12486661996',
#   'type': 'CreateEvent',
#   'actor': {'id': 61816001,
#    'login': 'Jihudumie',
#    'display_login': 'Jihudumie',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jihudumie',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61816001?'},
#   'repo': {'id': 268204609,
#    'name': 'Jihudumie/Quraan',
#    'url': 'https://api.github.com/repos/Jihudumie/Quraan'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-31T03:50:35Z'},
#  {'id': '12486662004',
#   'type': 'PushEvent',
#   'actor': {'id': 12245375,
#    'login': 'wskeee',
#    'display_login': 'wskeee',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wskeee',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12245375?'},
#   'repo': {'id': 177739450,
#    'name': 'wskeee/hellobabo',
#    'url': 'https://api.github.com/repos/wskeee/hellobabo'},
#   'payload': {'push_id': 5153533194,
#    'size': 3,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev-2.0.3',
#    'head': '650a7a490e4887293e4c45c55401d227bda55604',
#    'before': '5fb20473e4ee6821debd38a822667c0b3f90d18f',
#    'commits': [{'sha': '4b2e3618cd7ff5cbadcf5e70f42aed3845e4a1e1',
#      'author': {'email': 'wskeee@192.168.0.103', 'name': 'wskeee'},
#      'message': '修改配置',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/wskeee/hellobabo/commits/4b2e3618cd7ff5cbadcf5e70f42aed3845e4a1e1'},
#     {'sha': 'f6fab5e061420eb5f646557ef9c00f8cfd9cb94f',
#      'author': {'email': 'wskeee@192.168.0.103', 'name': 'wskeee'},
#      'message': '修改配置',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/wskeee/hellobabo/commits/f6fab5e061420eb5f646557ef9c00f8cfd9cb94f'},
#     {'sha': '650a7a490e4887293e4c45c55401d227bda55604',
#      'author': {'email': 'wskeee@192.168.0.103', 'name': 'wskeee'},
#      'message': "Merge branch 'dev-2.0.2' into dev-2.0.3",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wskeee/hellobabo/commits/650a7a490e4887293e4c45c55401d227bda55604'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:50:35Z'},
#  {'id': '12486661993',
#   'type': 'PushEvent',
#   'actor': {'id': 57289763,
#    'login': 'YadaYuki',
#    'display_login': 'YadaYuki',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/YadaYuki',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57289763?'},
#   'repo': {'id': 259221586,
#    'name': 'YadaYuki/effectivest-client',
#    'url': 'https://api.github.com/repos/YadaYuki/effectivest-client'},
#   'payload': {'push_id': 5153533185,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '479640296e349940134c970ab15a35a8ca4cc033',
#    'before': 'a5cbf212498bb366b91f2c7163d9538726b94d4b',
#    'commits': [{'sha': '479640296e349940134c970ab15a35a8ca4cc033',
#      'author': {'email': '57289763+YadaYuki@users.noreply.github.com',
#       'name': 'YadaYuki'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/YadaYuki/effectivest-client/commits/479640296e349940134c970ab15a35a8ca4cc033'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:50:35Z'},
#  {'id': '12486661995',
#   'type': 'PushEvent',
#   'actor': {'id': 22927164,
#    'login': 'mmmb1',
#    'display_login': 'mmmb1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmmb1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22927164?'},
#   'repo': {'id': 263933185,
#    'name': 'mmmb1/com.boxun.www',
#    'url': 'https://api.github.com/repos/mmmb1/com.boxun.www'},
#   'payload': {'push_id': 5153533188,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7a2f51839677fd8cdd70676aaf3a6b485c06fe5a',
#    'before': 'fd94920ebfe77e07e4c243d0eb078952882b72cc',
#    'commits': [{'sha': '7a2f51839677fd8cdd70676aaf3a6b485c06fe5a',
#      'author': {'email': 'tejoni2169@itiomail.com', 'name': 'tejoni'},
#      'message': 'update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmmb1/com.boxun.www/commits/7a2f51839677fd8cdd70676aaf3a6b485c06fe5a'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:50:35Z'},
#  {'id': '12486661987',
#   'type': 'ForkEvent',
#   'actor': {'id': 32573725,
#    'login': 'laurentlaurent',
#    'display_login': 'laurentlaurent',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/laurentlaurent',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32573725?'},
#   'repo': {'id': 217936522,
#    'name': 'jefflomacy/villagerdb',
#    'url': 'https://api.github.com/repos/jefflomacy/villagerdb'},
#   'payload': {'forkee': {'id': 268204608,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyNjgyMDQ2MDg=',
#     'name': 'villagerdb',
#     'full_name': 'laurentlaurent/villagerdb',
#     'private': False,
#     'owner': {'login': 'laurentlaurent',
#      'id': 32573725,
#      'node_id': 'MDQ6VXNlcjMyNTczNzI1',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/32573725?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/laurentlaurent',
#      'html_url': 'https://github.com/laurentlaurent',
#      'followers_url': 'https://api.github.com/users/laurentlaurent/followers',
#      'following_url': 'https://api.github.com/users/laurentlaurent/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/laurentlaurent/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/laurentlaurent/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/laurentlaurent/subscriptions',
#      'organizations_url': 'https://api.github.com/users/laurentlaurent/orgs',
#      'repos_url': 'https://api.github.com/users/laurentlaurent/repos',
#      'events_url': 'https://api.github.com/users/laurentlaurent/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/laurentlaurent/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/laurentlaurent/villagerdb',
#     'description': 'Animal Crossing Item and Villager Database',
#     'fork': True,
#     'url': 'https://api.github.com/repos/laurentlaurent/villagerdb',
#     'forks_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/forks',
#     'keys_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/teams',
#     'hooks_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/hooks',
#     'issue_events_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/events',
#     'assignees_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/tags',
#     'blobs_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/languages',
#     'stargazers_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/stargazers',
#     'contributors_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/contributors',
#     'subscribers_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/subscribers',
#     'subscription_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/subscription',
#     'commits_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/merges',
#     'archive_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/downloads',
#     'issues_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/laurentlaurent/villagerdb/deployments',
#     'created_at': '2020-05-31T03:50:34Z',
#     'updated_at': '2020-05-31T03:50:27Z',
#     'pushed_at': '2020-05-30T11:49:18Z',
#     'git_url': 'git://github.com/laurentlaurent/villagerdb.git',
#     'ssh_url': 'git@github.com:laurentlaurent/villagerdb.git',
#     'clone_url': 'https://github.com/laurentlaurent/villagerdb.git',
#     'svn_url': 'https://github.com/laurentlaurent/villagerdb',
#     'homepage': 'https://villagerdb.com',
#     'size': 3283,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'gpl-3.0',
#      'name': 'GNU General Public License v3.0',
#      'spdx_id': 'GPL-3.0',
#      'url': 'https://api.github.com/licenses/gpl-3.0',
#      'node_id': 'MDc6TGljZW5zZTk='},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-05-31T03:50:35Z'},
#  {'id': '12486661981',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 2666849,
#    'login': 'senorsmile',
#    'display_login': 'senorsmile',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/senorsmile',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2666849?'},
#   'repo': {'id': 119992165,
#    'name': 'jD91mZM2/xidlehook',
#    'url': 'https://api.github.com/repos/jD91mZM2/xidlehook'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/jD91mZM2/xidlehook/issues/44',
#     'repository_url': 'https://api.github.com/repos/jD91mZM2/xidlehook',
#     'labels_url': 'https://api.github.com/repos/jD91mZM2/xidlehook/issues/44/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/jD91mZM2/xidlehook/issues/44/comments',
#     'events_url': 'https://api.github.com/repos/jD91mZM2/xidlehook/issues/44/events',
#     'html_url': 'https://github.com/jD91mZM2/xidlehook/issues/44',
#     'id': 627830671,
#     'node_id': 'MDU6SXNzdWU2Mjc4MzA2NzE=',
#     'number': 44,
#     'title': 'E0277 and E0308 when running `cargo install xidlehook --bins` in Ubuntu 20.04',
#     'user': {'login': 'alvarop',
#      'id': 744129,
#      'node_id': 'MDQ6VXNlcjc0NDEyOQ==',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/744129?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/alvarop',
#      'html_url': 'https://github.com/alvarop',
#      'followers_url': 'https://api.github.com/users/alvarop/followers',
#      'following_url': 'https://api.github.com/users/alvarop/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/alvarop/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/alvarop/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/alvarop/subscriptions',
#      'organizations_url': 'https://api.github.com/users/alvarop/orgs',
#      'repos_url': 'https://api.github.com/users/alvarop/repos',
#      'events_url': 'https://api.github.com/users/alvarop/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/alvarop/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2020-05-30T21:52:31Z',
#     'updated_at': '2020-05-31T03:50:34Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': 'I tried installing with `cargo install xidlehook --bins` and got the following errors:\r\n\r\nNever used rust before so I\'m not sure what I can do to fix it.\r\nI\'m using Ubuntu 20.04 and rustc/cargo 1.41.0.\r\n\r\n```\r\n$cargo install xidlehook --bins\r\n   Updating crates.io index\r\n   Installing xidlehook v0.8.2\r\n   Compiling proc-macro2 v1.0.17\r\n   Compiling unicode-xid v0.2.0\r\n   Compiling syn v1.0.29\r\n   Compiling libc v0.2.71\r\n   Compiling cfg-if v0.1.10\r\n   Compiling autocfg v1.0.0\r\n   Compiling lazy_static v1.4.0\r\n   Compiling memchr v2.3.3\r\n   Compiling maybe-uninit v2.0.0\r\n   Compiling version_check v0.9.2\r\n   Compiling bitflags v1.2.1\r\n   Compiling pkg-config v0.3.17\r\n   Compiling proc-macro-nested v0.1.4\r\n   Compiling futures-core v0.3.5\r\n   Compiling once_cell v1.4.0\r\n   Compiling futures-sink v0.3.5\r\n   Compiling proc-macro-hack v0.5.16\r\n   Compiling futures-io v0.3.5\r\n   Compiling log v0.4.8\r\n   Compiling slab v0.4.2\r\n   Compiling pin-utils v0.1.0\r\n   Compiling scopeguard v1.1.0\r\n   Compiling void v1.0.2\r\n   Compiling nix v0.17.0\r\n   Compiling unicode-width v0.1.7\r\n   Compiling unicode-segmentation v1.6.0\r\n   Compiling ansi_term v0.11.0\r\n   Compiling strsim v0.8.0\r\n   Compiling serde v1.0.111\r\n   Compiling async-task v3.0.0\r\n   Compiling nix v0.15.0\r\n   Compiling vec_map v0.8.2\r\n   Compiling ryu v1.0.4\r\n   Compiling scoped-tls-hkt v0.1.2\r\n   Compiling regex-syntax v0.6.18\r\n   Compiling quick-error v1.2.3\r\n   Compiling pin-project-lite v0.1.5\r\n   Compiling itoa v0.4.5\r\n   Compiling termcolor v1.1.0\r\n   Compiling thread_local v1.0.1\r\n   Compiling futures-channel v0.3.5\r\n   Compiling futures-task v0.3.5\r\n   Compiling textwrap v0.11.0\r\n   Compiling heck v0.3.1\r\n   Compiling crossbeam-utils v0.7.2\r\n   Compiling memoffset v0.5.4\r\n   Compiling crossbeam-epoch v0.8.2\r\n   Compiling proc-macro-error-attr v1.0.2\r\n   Compiling proc-macro-error v1.0.2\r\n   Compiling humantime v1.3.0\r\n   Compiling x11 v2.18.2\r\n   Compiling libpulse-sys v1.13.0\r\n   Compiling aho-corasick v0.7.10\r\n   Compiling quote v1.0.6\r\n   Compiling kv-log-macro v1.0.6\r\n   Compiling crossbeam-queue v0.2.2\r\n   Compiling crossbeam-channel v0.4.2\r\n   Compiling regex v1.3.9\r\n   Compiling atty v0.2.14\r\n   Compiling socket2 v0.3.12\r\n   Compiling num_cpus v1.13.0\r\n   Compiling crossbeam-deque v0.7.3\r\n   Compiling clap v2.33.1\r\n   Compiling xcb v0.9.0\r\n   Compiling libpulse-binding v2.15.1\r\n   Compiling env_logger v0.7.1\r\n   Compiling syn-mid v0.5.0\r\n   Compiling crossbeam v0.7.3\r\n   Compiling pin-project-internal v0.4.17\r\n   Compiling futures-macro v0.3.5\r\n   Compiling serde_derive v1.0.111\r\n   Compiling structopt-derive v0.4.7\r\n   Compiling pin-project v0.4.17\r\n   Compiling futures-util v0.3.5\r\n   Compiling piper v0.1.2\r\n   Compiling futures-executor v0.3.5\r\n   Compiling futures v0.3.5\r\n   Compiling smol v0.1.10\r\n   Compiling async-std v1.6.0\r\n   Compiling structopt v0.3.14\r\n   Compiling serde_json v1.0.53\r\n   Compiling xidlehook-core v0.1.1\r\n   Compiling xidlehook v0.8.2\r\nerror[E0308]: mismatched types\r\n   --> /home/alvaro/.cargo/registry/src/github.com-1ecc6299db9ec823/xidlehook-0.8.2/src/main.rs:176:38\r\n    |\r\n176 |                     Selected::Socket(rx.recv().await)\r\n    |                                      ^^^^^^^^^^^^^^^ expected enum `std::option::Option`, found enum `std::result::Result`\r\n    |\r\n    = note: expected enum `std::option::Option<(socket::models::Message, async_std::sync::channel::Sender<socket::models::Reply>)>`\r\n               found enum `std::result::Result<(socket::models::Message, async_std::sync::channel::Sender<socket::models::Reply>), async_std::sync::channel::RecvError>`\r\n\r\nerror[E0308]: mismatched types\r\n   --> /home/alvaro/.cargo/registry/src/github.com-1ecc6299db9ec823/xidlehook-0.8.2/src/main.rs:183:38\r\n    |\r\n183 |       ...
#    'comment': {'url': 'https://api.github.com/repos/jD91mZM2/xidlehook/issues/comments/636416676',
#     'html_url': 'https://github.com/jD91mZM2/xidlehook/issues/44#issuecomment-636416676',
#     'issue_url': 'https://api.github.com/repos/jD91mZM2/xidlehook/issues/44',
#     'id': 636416676,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDYzNjQxNjY3Ng==',
#     'user': {'login': 'senorsmile',
#      'id': 2666849,
#      'node_id': 'MDQ6VXNlcjI2NjY4NDk=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/2666849?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/senorsmile',
#      'html_url': 'https://github.com/senorsmile',
#      'followers_url': 'https://api.github.com/users/senorsmile/followers',
#      'following_url': 'https://api.github.com/users/senorsmile/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/senorsmile/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/senorsmile/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/senorsmile/subscriptions',
#      'organizations_url': 'https://api.github.com/users/senorsmile/orgs',
#      'repos_url': 'https://api.github.com/users/senorsmile/repos',
#      'events_url': 'https://api.github.com/users/senorsmile/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/senorsmile/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-05-31T03:50:34Z',
#     'updated_at': '2020-05-31T03:50:34Z',
#     'author_association': 'NONE',
#     'body': "I installed the nix package manager and tried following the directions to install that way, but it doesn't seem to work at all.  Opening a separate issue for that. "}},
#   'public': True,
#   'created_at': '2020-05-31T03:50:35Z'},
#  {'id': '12486661982',
#   'type': 'CreateEvent',
#   'actor': {'id': 53976121,
#    'login': 'CrisTianZG',
#    'display_login': 'CrisTianZG',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CrisTianZG',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53976121?'},
#   'repo': {'id': 268025167,
#    'name': '3lCR3P3R/GlobHack-Pitanza',
#    'url': 'https://api.github.com/repos/3lCR3P3R/GlobHack-Pitanza'},
#   'payload': {'ref': 'comidas',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-31T03:50:35Z'},
#  {'id': '12486661978',
#   'type': 'PushEvent',
#   'actor': {'id': 61995165,
#    'login': 'chimbinde',
#    'display_login': 'chimbinde',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chimbinde',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61995165?'},
#   'repo': {'id': 268202563,
#    'name': 'chimbinde/mini-proj1',
#    'url': 'https://api.github.com/repos/chimbinde/mini-proj1'},
#   'payload': {'push_id': 5153533178,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1e3d8f60dfc87c17748608991ab01f4feba61136',
#    'before': '600f0add00521bbd5350e325403f68d8d25868c4',
#    'commits': [{'sha': '1e3d8f60dfc87c17748608991ab01f4feba61136',
#      'author': {'email': '61995165+chimbinde@users.noreply.github.com',
#       'name': 'chimbinde'},
#      'message': 'Delete angular.mini.js',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/chimbinde/mini-proj1/commits/1e3d8f60dfc87c17748608991ab01f4feba61136'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:50:35Z'},
#  {'id': '12486661979',
#   'type': 'WatchEvent',
#   'actor': {'id': 278392,
#    'login': 'magicwind',
#    'display_login': 'magicwind',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/magicwind',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/278392?'},
#   'repo': {'id': 260561536,
#    'name': 'heyxiaobai/MSI-B450m-MORTAR-Hackintosh',
#    'url': 'https://api.github.com/repos/heyxiaobai/MSI-B450m-MORTAR-Hackintosh'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-05-31T03:50:35Z'},
#  {'id': '12486661980',
#   'type': 'WatchEvent',
#   'actor': {'id': 2419,
#    'login': 'shuber',
#    'display_login': 'shuber',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shuber',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2419?'},
#   'repo': {'id': 11771434,
#    'name': 'codetriage/maildown',
#    'url': 'https://api.github.com/repos/codetriage/maildown'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-05-31T03:50:35Z',
#   'org': {'id': 2896855,
#    'login': 'codetriage',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/codetriage',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2896855?'}},
#  {'id': '12486661974',
#   'type': 'PushEvent',
#   'actor': {'id': 45079819,
#    'login': 'Diegonavia',
#    'display_login': 'Diegonavia',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Diegonavia',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45079819?'},
#   'repo': {'id': 267944452,
#    'name': 'Diegonavia/api-example',
#    'url': 'https://api.github.com/repos/Diegonavia/api-example'},
#   'payload': {'push_id': 5153533175,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '724e68396b0ce69124a39f11884d50f02daa9080',
#    'before': 'e5783bda5a838012a864a174303592838dbd7218',
#    'commits': [{'sha': '724e68396b0ce69124a39f11884d50f02daa9080',
#      'author': {'email': 'test@MacBook-Pro-de-test.local', 'name': 'test'},
#      'message': 'testing dockerfile',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Diegonavia/api-example/commits/724e68396b0ce69124a39f11884d50f02daa9080'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:50:34Z'},
#  {'id': '12486661973',
#   'type': 'PushEvent',
#   'actor': {'id': 3248921,
#    'login': 'rpartha',
#    'display_login': 'rpartha',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rpartha',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3248921?'},
#   'repo': {'id': 249875430,
#    'name': 'rpartha/rpartha.github.io',
#    'url': 'https://api.github.com/repos/rpartha/rpartha.github.io'},
#   'payload': {'push_id': 5153533174,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b0f368b21a64b9f597ec7342dd97d95e39be6b4b',
#    'before': 'ceeca58af2a3320c72c31e5570832b76c3f0607a',
#    'commits': [{'sha': 'b0f368b21a64b9f597ec7342dd97d95e39be6b4b',
#      'author': {'email': 'travis@example.org', 'name': 'Travis CI User'},
#      'message': 'Regenerated static content for 2ca1e96868a57031696294e0ed9cd6f217fc1ba3',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rpartha/rpartha.github.io/commits/b0f368b21a64b9f597ec7342dd97d95e39be6b4b'}]},
#   'public': True,
#   'created_at': '2020-05-31T03:50:34Z'},
#  {'id': '12486661972',
#   'type': 'WatchEvent',
#   'actor': {'id': 33695929,
#    'login': 'ztaylor20',
#    'display_login': 'ztaylor20',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ztaylor20',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33695929?'},
#   'repo': {'id': 243960588,
#    'name': 'Darkflame72/Obsidion',
#    'url': 'https://api.github.com/repos/Darkflame72/Obsidion'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-05-31T03:50:34Z'}]
